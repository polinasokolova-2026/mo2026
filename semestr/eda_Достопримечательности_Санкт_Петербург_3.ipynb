# %% [markdown]
# # Разведочный анализ данных для набора данных: Достопримечательности_Санкт_Петербург

# %% [markdown]
# ## Задание
#
# Вам предлагается выполнить разведочный анализ данных и описать полученные результаты
#
# Описание набора данных: https://data.gov.spb.ru/irsi/7842489089-dostoprimechatelnosti/structure_version/157/
#
# Ссылка на набор данных для использования в блокноте: https://raw.githubusercontent.com/yakushinav/journ/refs/heads/main/datasets/dostoprimechatelnosti.csv

# %% [markdown]
# #### 1. Подключение библиотек

# %%
# Ваш код здесь

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from warnings import filterwarnings
filterwarnings(action='ignore')

# %% [markdown]
# #### 2. Чтение набора данных

# %%
# Ваш код здесь

url = 'https://raw.githubusercontent.com/yakushinav/journ/refs/heads/main/datasets/dostoprimechatelnosti.csv'

data = pd.read_csv(url)

data.head(5)
# Out:
#    ID в ИС ГТИБД          Вид объекта  \
# 0           5827  Религиозные объекты
# 1           5828  Религиозные объекты
# 2           5829  Религиозные объекты
# 3           5830  Религиозные объекты
# 4           5831  Религиозные объекты
#
#                                             Название  \
# 0                     Армянская апостольская церковь
# 1  Армянская Апостольская Церковь Святого Воскрес...
# 2  Санкт-Петербургский буддийский храм Дацан Гунз...
# 3                                 Коломяжская мечеть
# 4                   Соборная мечеть Санкт-Петербурга
#
#                  Краткое название         Название (англ.)  \
# 0  Армянская Апостольская Церковь   St. Catherine's Church
# 1     Церковь Святого Воскресения  St. Ressurection Church
# 2               Дацан Гунзэчойнэй      Datsan Gunzechoinei
# 3              Коломяжская мечеть    Kolomyazhskaya Mosque
# 4                 Соборная мечеть  Saint Petersburg Mosque
#
#                Тип учреждения                             Адрес (ручной)  \
# 0  некоммерческая организация     Санкт-Петербург, Невский пр., д. 40-42
# 1  некоммерческая организация  Санкт-Петербург, наб. реки Смоленки, д.29
# 2  некоммерческая организация      Санкт-Петербург, Приморский пр., д.91
# 3  некоммерческая организация         Санкт-Петербург, Репищева ул., д.1
# 4  некоммерческая организация     Санкт-Петербург, Кронверкский пр., д.7
#
#                          Телефоны                 Сайт  \
# 0  +7(812)5704108; +7(812)7105061  armenian-church.org
# 1                  +7(812)3505301  armenian-church.org
# 2                  +7(981)7559605         dazan.spb.ru
# 3                             NaN                  NaN
# 4                  +7(812)4984075           dum-spb.ru
#
#         Электронная почта                                           Описание  \
# 0  arm_church_spb@mail.ru  Здание было построено архитектором Ю. М. Фельт...
# 1  arm_church_spb@mail.ru  Возведенная в традициях русского классицизма, ...
# 2                     NaN  "Оригинальный храм из красно-фиолетового грани...
# 3                     NaN  Коломяжскую мечеть, расположившуюся в Приморск...
# 4         dum-spb@mail.ru  "Здание Соборной мечети – яркий образец архите...
#
#   Описание (англ.)                               Историческая справка  \
# 0              NaN  22 мая (2 июня) 1770 года по челобитной главы ...
# 1              NaN  "Храм строился по инициативе и на средства гла...
# 2              NaN  Санкт-Петербургский буддийский храм был постро...
# 3              NaN  Квартальная джума-мечеть построена по заказу Д...
# 4              NaN  "Еще в конце XVIII века около 500 нижних чинов...
#
#   Историческая справка (англ.)  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#                                              Заметки  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Часы работы не указаны. Можно записаться на эк...
#
#                                         Режим работы Режим работы (англ.)  \
# 0                              09:00–19:00, ежеднвно                  NaN
# 1                             09:00–18:00, ежедневно                  NaN
# 2  Ежедневно с 10:00 до 19:00. Выходной день - ср...                  NaN
# 3                            Понедельник 12:00-20:00                  NaN
# 4                                                NaN                  NaN
#
#                   Координаты  Координата_X  Координата_Y
# 0  59.957114107,30.303121017     59.957114     30.303121
# 1  59.947875533,30.253260955     59.947876     30.253261
# 2  59.983492135,30.255973046     59.983492     30.255973
# 3  60.017749506,30.281070461     60.017750     30.281070
# 4   59.955200609,30.32390419     59.955201     30.323904

# %% [markdown]
# #### 3. Первые 5 строк набора данных

# %%
# Ваш код здесь

data.head(5)
# Out:
#    ID в ИС ГТИБД          Вид объекта  \
# 0           5827  Религиозные объекты
# 1           5828  Религиозные объекты
# 2           5829  Религиозные объекты
# 3           5830  Религиозные объекты
# 4           5831  Религиозные объекты
#
#                                             Название  \
# 0                     Армянская апостольская церковь
# 1  Армянская Апостольская Церковь Святого Воскрес...
# 2  Санкт-Петербургский буддийский храм Дацан Гунз...
# 3                                 Коломяжская мечеть
# 4                   Соборная мечеть Санкт-Петербурга
#
#                  Краткое название         Название (англ.)  \
# 0  Армянская Апостольская Церковь   St. Catherine's Church
# 1     Церковь Святого Воскресения  St. Ressurection Church
# 2               Дацан Гунзэчойнэй      Datsan Gunzechoinei
# 3              Коломяжская мечеть    Kolomyazhskaya Mosque
# 4                 Соборная мечеть  Saint Petersburg Mosque
#
#                Тип учреждения                             Адрес (ручной)  \
# 0  некоммерческая организация     Санкт-Петербург, Невский пр., д. 40-42
# 1  некоммерческая организация  Санкт-Петербург, наб. реки Смоленки, д.29
# 2  некоммерческая организация      Санкт-Петербург, Приморский пр., д.91
# 3  некоммерческая организация         Санкт-Петербург, Репищева ул., д.1
# 4  некоммерческая организация     Санкт-Петербург, Кронверкский пр., д.7
#
#                          Телефоны                 Сайт  \
# 0  +7(812)5704108; +7(812)7105061  armenian-church.org
# 1                  +7(812)3505301  armenian-church.org
# 2                  +7(981)7559605         dazan.spb.ru
# 3                             NaN                  NaN
# 4                  +7(812)4984075           dum-spb.ru
#
#         Электронная почта                                           Описание  \
# 0  arm_church_spb@mail.ru  Здание было построено архитектором Ю. М. Фельт...
# 1  arm_church_spb@mail.ru  Возведенная в традициях русского классицизма, ...
# 2                     NaN  "Оригинальный храм из красно-фиолетового грани...
# 3                     NaN  Коломяжскую мечеть, расположившуюся в Приморск...
# 4         dum-spb@mail.ru  "Здание Соборной мечети – яркий образец архите...
#
#   Описание (англ.)                               Историческая справка  \
# 0              NaN  22 мая (2 июня) 1770 года по челобитной главы ...
# 1              NaN  "Храм строился по инициативе и на средства гла...
# 2              NaN  Санкт-Петербургский буддийский храм был постро...
# 3              NaN  Квартальная джума-мечеть построена по заказу Д...
# 4              NaN  "Еще в конце XVIII века около 500 нижних чинов...
#
#   Историческая справка (англ.)  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#                                              Заметки  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Часы работы не указаны. Можно записаться на эк...
#
#                                         Режим работы Режим работы (англ.)  \
# 0                              09:00–19:00, ежеднвно                  NaN
# 1                             09:00–18:00, ежедневно                  NaN
# 2  Ежедневно с 10:00 до 19:00. Выходной день - ср...                  NaN
# 3                            Понедельник 12:00-20:00                  NaN
# 4                                                NaN                  NaN
#
#                   Координаты  Координата_X  Координата_Y
# 0  59.957114107,30.303121017     59.957114     30.303121
# 1  59.947875533,30.253260955     59.947876     30.253261
# 2  59.983492135,30.255973046     59.983492     30.255973
# 3  60.017749506,30.281070461     60.017750     30.281070
# 4   59.955200609,30.32390419     59.955201     30.323904

# %% [markdown]
# #### 4. Последние 7 строк набора данных

# %%
# Ваш код здесь

data.tail(7)
# Out:
#      ID в ИС ГТИБД        Вид объекта                           Название  \
# 687          19574  Природные объекты                  Линдуловская роща
# 688          19575  Природные объекты                   Борницкий карьер
# 689          19576  Природные объекты                    Радоновые озера
# 690          19577  Природные объекты                  Суздальские озера
# 691          19578  Природные объекты             Новоорловский заказник
# 692           9160   Замки и крепости  Михайловский или Инженерный замок
# 693          12852   Замки и крепости           Петропавловская Крепость
#
#     Краткое название                              Название (англ.)  \
# 687              NaN                             Lindulovsky Grove
# 688              NaN                              Bornitsky Quarry
# 689              NaN                                   Radon Lakes
# 690              NaN                                  Suzdal Lakes
# 691              NaN                          Novoorlovsky Reserve
# 692              NaN  Mikhailovsky Castle or the Engineers' Castle
# 693              NaN                       Peter and Paul Fortress
#
#     Тип учреждения                                     Адрес (ручной)  \
# 687            NaN                 Ленинградская обл., Выборгский р-н
# 688            NaN  Ленинградская обл.,д. Новое Хинколово, Гатчинс...
# 689            NaN                    д.Лопухинка, Ленинградская обл.
# 690            NaN  Cанкт-Петербург, Выборгский р-н, Шувалово-Озер...
# 691            NaN                    Санкт-Петербург, Приморский р-н
# 692            NaN  ул.Садовая, 2 (метро - "Гостиный двор","Невски...
# 693            NaN                   Санкт-Петербург, 197046 o.Заячий
#
#                Телефоны                                              Сайт  \
# 687                 NaN                                               NaN
# 688                 NaN                                               NaN
# 689                 NaN                                               NaN
# 690                 NaN                                               NaN
# 691   +7 812) 242-33-77  http://oopt.spb.ru/protected_area/novoorlovskiy/
# 692  +7 (812) 595-42-48                                  www.rusmuseum.ru
# 693  +7 (812) 230-64-31                                  www.spbmuseum.ru
#
#              Электронная почта  \
# 687                        NaN
# 688                        NaN
# 689                        NaN
# 690                        NaN
# 691  dep@oopt.kpoos.gov.spb.ru
# 692          info@rusmuseum.ru
# 693           gmi@spbmuseum.ru
#
#                                               Описание  \
# 687  Старейшая в Европе лиственничная роща почти на...
# 688  В 30 минутых от деревни Новое Хинколово, что в...
# 689  В Ленинградской области в деревне Лопухинка ес...
# 690  Три Суздальских озера расположены недалеко дру...
# 691  Растительный покров Новоорловского заказника н...
# 692  Михайловский или Инженерный замок - бывший имп...
# 693  В 1908 году по инициативе известных исследоват...
#
#                                       Описание (англ.)  \
# 687  The oldest larch grove in Europe on almost 1 t...
# 688  30 minutes from the village of Novoe Khinkolov...
# 689  In the Leningrad region, in the village of Lop...
# 690  Three Suzdal lakes are located not far from ea...
# 691  Растительный покров Новоорловского заказника н...
# 692  St. Michael's Castle (also called the Mikhailo...
# 693  The Museum of Old Petersburg was initiated in ...
#
#                                   Историческая справка  \
# 687                                                NaN
# 688                                                NaN
# 689                                                NaN
# 690                                                NaN
# 691  Первое письменное упоминание населенных пункто...
# 692                                                NaN
# 693                                                NaN
#
#                           Историческая справка (англ.)  \
# 687                                                NaN
# 688                                                NaN
# 689                                                NaN
# 690                                                NaN
# 691  The first written mention of settlements locat...
# 692                                                NaN
# 693                                                NaN
#
#                                                Заметки  \
# 687  От Финляндского вокзала до ж/д ст. «Рощино», д...
# 688  Необходимо будет доехать до Гатчины и после на...
# 689  Как добраться: электричкой от Балтийского вокз...
# 690        Как добраться: пешком от ст. метро "Озерки"
# 691  Добраться до заказника можно: от станции метро...
# 692                                                NaN
# 693                                                NaN
#
#                                           Режим работы Режим работы (англ.)  \
# 687                                                NaN                  NaN
# 688                                                NaN                  NaN
# 689                                                NaN                  NaN
# 690                                                NaN                  NaN
# 691  Работает ежедневно, круглосуточно выходные бес...                  NaN
# 692                                                NaN                  NaN
# 693                                                NaN                  NaN
#
#                     Координаты  Координата_X  Координата_Y
# 687        60.237324,29.539703     60.237324     29.539703
# 688        59.488063,29.938278     59.488063     29.938278
# 689        59.734545,29.401247     59.734545     29.401247
# 690         60.057625,30.30438     60.057625     30.304380
# 691          60.049967,30.2892     60.049967     30.289200
# 692  59.940205114,30.337045054     59.940205     30.337045
# 693        59.950154,30.315877     59.950154     30.315877

# %% [markdown]
# #### 5. Поля набора данных

# %%
# Ваш код здесь

data.columns
# Out:
# Index(['ID в ИС ГТИБД', 'Вид объекта', 'Название', 'Краткое название',
#        'Название (англ.)', 'Тип учреждения', 'Адрес (ручной)', 'Телефоны',
#        'Сайт', 'Электронная почта', 'Описание', 'Описание (англ.)',
#        'Историческая справка', 'Историческая справка (англ.)', 'Заметки',
#        'Режим работы', 'Режим работы (англ.)', 'Координаты', 'Координата_X',
#        'Координата_Y'],
#       dtype='object')

# %% [markdown]
# #### 6. Размер набора данных (количество полей и строк)

# %%
# Ваш код здесь

data.shape
# Out:
# (694, 20)

# %% [markdown]
# #### 7. Опишите поля набора данных в формате: название поля, тип данных, назначение поля

# %%
# Ваш код здесь

for col in data.columns:
    print(f'Поле: {col}')
    print(f'Тип данных: {data[col].dtype}')
    print()
# Out:
# Поле: ID в ИС ГТИБД
# Тип данных: int64
#
# Поле: Вид объекта
# Тип данных: object
#
# Поле: Название
# Тип данных: object
#
# Поле: Краткое название
# Тип данных: object
#
# Поле: Название (англ.)
# Тип данных: object
#
# Поле: Тип учреждения
# Тип данных: object
#
# Поле: Адрес (ручной)
# Тип данных: object
#
# Поле: Телефоны
# Тип данных: object
#
# Поле: Сайт
# Тип данных: object
#
# Поле: Электронная почта
# Тип данных: object
#
# Поле: Описание
# Тип данных: object
#
# Поле: Описание (англ.)
# Тип данных: object
#
# Поле: Историческая справка
# Тип данных: object
#
# Поле: Историческая справка (англ.)
# Тип данных: object
#
# Поле: Заметки
# Тип данных: object
#
# Поле: Режим работы
# Тип данных: object
#
# Поле: Режим работы (англ.)
# Тип данных: object
#
# Поле: Координаты
# Тип данных: object
#
# Поле: Координата_X
# Тип данных: float64
#
# Поле: Координата_Y
# Тип данных: float64

# %% [markdown]
# #### 8. Информация о наборе данных

# %%
# Ваш код здесь

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 694 entries, 0 to 693
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID в ИС ГТИБД                 694 non-null    int64
#  1   Вид объекта                   694 non-null    object
#  2   Название                      694 non-null    object
#  3   Краткое название              183 non-null    object
#  4   Название (англ.)              689 non-null    object
#  5   Тип учреждения                197 non-null    object
#  6   Адрес (ручной)                692 non-null    object
#  7   Телефоны                      218 non-null    object
#  8   Сайт                          194 non-null    object
#  9   Электронная почта             169 non-null    object
#  10  Описание                      522 non-null    object
#  11  Описание (англ.)              274 non-null    object
#  12  Историческая справка          369 non-null    object
#  13  Историческая справка (англ.)  197 non-null    object
#  14  Заметки                       25 non-null     object
#  15  Режим работы                  466 non-null    object
#  16  Режим работы (англ.)          289 non-null    object
#  17  Координаты                    694 non-null    object
#  18  Координата_X                  694 non-null    float64
#  19  Координата_Y                  694 non-null    float64
# dtypes: float64(2), int64(1), object(17)
# memory usage: 108.6+ KB

# %% [markdown]
# #### 9. Описательная статистика для числовых полей

# %%
# Ваш код здесь

data.describe()
# Out:
#        ID в ИС ГТИБД  Координата_X  Координата_Y
# count     694.000000    694.000000    694.000000
# mean     8602.600865     59.924574     30.299384
# std      3287.285900      0.109774      0.294819
# min      3281.000000     58.845235     28.727875
# 25%      5970.250000     59.905064     30.285369
# 50%      6921.500000     59.932854     30.319803
# 75%      9075.500000     59.957467     30.361939
# max     19578.000000     60.732605     34.211861

# %% [markdown]
# #### 10. Описательная статистика для категориальных полей

# %%
# Ваш код здесь

data.describe(include='object')
# Out:
#        Вид объекта                                   Название  \
# count          694                                        694
# unique           6                                        691
# top      Памятники  Церковь Благовещения Пресвятой Богородицы
# freq           235                                          2
#
#              Краткое название             Название (англ.)  \
# count                     183                          689
# unique                    173                          686
# top     Церковь Петра и Павла  Our Lady of Vladimir Church
# freq                        3                            2
#
#                     Тип учреждения  \
# count                          197
# unique                          35
# top     некоммерческая организация
# freq                            37
#
#                                            Адрес (ручной)            Телефоны  \
# count                                                 692                 218
# unique                                                666                 193
# top     г. Санкт-Петербург, Аллея Героев Московского п...  +7 (812) 233-00-05
# freq                                                    9                   8
#
#        Сайт Электронная почта Описание Описание (англ.) Историческая справка  \
# count   194               169      522              274                  369
# unique  173               127      514              273                  365
# top     нет               нет  Церковь    круглосуточно           не указано
# freq     10                16        5                2                    4
#
#                              Историческая справка (англ.)  \
# count                                                 197
# unique                                                197
# top     Garden in Admiralteisky district of St. Peters...
# freq                                                    1
#
#                                                   Заметки   Режим работы  \
# count                                                  25            466
# unique                                                 25            179
# top     Часы работы не указаны. Можно записаться на эк...  Круглосуточно
# freq                                                    1            116
#
#        Режим работы (англ.)                 Координаты
# count                   289                        694
# unique                   47                        657
# top                24 hours  59.975070214,30.311704745
# freq                    201                          4

# %% [markdown]
# #### 11. Проверка наличия пропусков в данных

# %%
# Ваш код здесь

data.isnull().sum()
# Out:
# ID в ИС ГТИБД                     0
# Вид объекта                       0
# Название                          0
# Краткое название                511
# Название (англ.)                  5
# Тип учреждения                  497
# Адрес (ручной)                    2
# Телефоны                        476
# Сайт                            500
# Электронная почта               525
# Описание                        172
# Описание (англ.)                420
# Историческая справка            325
# Историческая справка (англ.)    497
# Заметки                         669
# Режим работы                    228
# Режим работы (англ.)            405
# Координаты                        0
# Координата_X                      0
# Координата_Y                      0
# dtype: int64

# %% [markdown]
# #### 12. Если вы обнаружили пропуски в данных, то заполните их на основе среднего или медианы или моды

# %%
# Ваш код здесь

print('Количество пропусков до заполнения:')
print(data.isnull().sum())

for column in data.columns:


    if data[column].dtype == 'int64' or data[column].dtype == 'float64':
        data[column].fillna(data[column].mean(), inplace=True)
    else:
        data[column].fillna(data[column].mode()[0], inplace=True)

print('\nКоличество пропусков после заполнения:')
print(data.isnull().sum())
# Out:
# Количество пропусков до заполнения:
# ID в ИС ГТИБД                     0
# Вид объекта                       0
# Название                          0
# Краткое название                511
# Название (англ.)                  5
# Тип учреждения                  497
# Адрес (ручной)                    2
# Телефоны                        476
# Сайт                            500
# Электронная почта               525
# Описание                        172
# Описание (англ.)                420
# Историческая справка            325
# Историческая справка (англ.)    497
# Заметки                         669
# Режим работы                    228
# Режим работы (англ.)            405
# Координаты                        0
# Координата_X                      0
# Координата_Y                      0
# dtype: int64
#
# Количество пропусков после заполнения:
# ID в ИС ГТИБД                   0
# Вид объекта                     0
# Название                        0
# Краткое название                0
# Название (англ.)                0
# Тип учреждения                  0
# Адрес (ручной)                  0
# Телефоны                        0
# Сайт                            0
# Электронная почта               0
# Описание                        0
# Описание (англ.)                0
# Историческая справка            0
# Историческая справка (англ.)    0
# Заметки                         0
# Режим работы                    0
# Режим работы (англ.)            0
# Координаты                      0
# Координата_X                    0
# Координата_Y                    0
# dtype: int64

# %% [markdown]
# #### 13. Фильтрация. Выберите все строки таблицы, для которых значение поля Координата_X больше 59.0

# %%
# Ваш код здесь

data[data['Координата_X'] > 59.0]
# Out:
#      ID в ИС ГТИБД          Вид объекта  \
# 0             5827  Религиозные объекты
# 1             5828  Религиозные объекты
# 2             5829  Религиозные объекты
# 3             5830  Религиозные объекты
# 4             5831  Религиозные объекты
# ..             ...                  ...
# 689          19576    Природные объекты
# 690          19577    Природные объекты
# 691          19578    Природные объекты
# 692           9160     Замки и крепости
# 693          12852     Замки и крепости
#
#                                               Название  \
# 0                       Армянская апостольская церковь
# 1    Армянская Апостольская Церковь Святого Воскрес...
# 2    Санкт-Петербургский буддийский храм Дацан Гунз...
# 3                                   Коломяжская мечеть
# 4                     Соборная мечеть Санкт-Петербурга
# ..                                                 ...
# 689                                    Радоновые озера
# 690                                  Суздальские озера
# 691                             Новоорловский заказник
# 692                  Михайловский или Инженерный замок
# 693                           Петропавловская Крепость
#
#                    Краткое название  \
# 0    Армянская Апостольская Церковь
# 1       Церковь Святого Воскресения
# 2                 Дацан Гунзэчойнэй
# 3                Коломяжская мечеть
# 4                   Соборная мечеть
# ..                              ...
# 689           Церковь Петра и Павла
# 690           Церковь Петра и Павла
# 691           Церковь Петра и Павла
# 692           Церковь Петра и Павла
# 693           Церковь Петра и Павла
#
#                                  Название (англ.)              Тип учреждения  \
# 0                          St. Catherine's Church  некоммерческая организация
# 1                         St. Ressurection Church  некоммерческая организация
# 2                             Datsan Gunzechoinei  некоммерческая организация
# 3                           Kolomyazhskaya Mosque  некоммерческая организация
# 4                         Saint Petersburg Mosque  некоммерческая организация
# ..                                            ...                         ...
# 689                                   Radon Lakes  некоммерческая организация
# 690                                  Suzdal Lakes  некоммерческая организация
# 691                          Novoorlovsky Reserve  некоммерческая организация
# 692  Mikhailovsky Castle or the Engineers' Castle  некоммерческая организация
# 693                       Peter and Paul Fortress  некоммерческая организация
#
#                                         Адрес (ручной)  \
# 0               Санкт-Петербург, Невский пр., д. 40-42
# 1            Санкт-Петербург, наб. реки Смоленки, д.29
# 2                Санкт-Петербург, Приморский пр., д.91
# 3                   Санкт-Петербург, Репищева ул., д.1
# 4               Санкт-Петербург, Кронверкский пр., д.7
# ..                                                 ...
# 689                    д.Лопухинка, Ленинградская обл.
# 690  Cанкт-Петербург, Выборгский р-н, Шувалово-Озер...
# 691                    Санкт-Петербург, Приморский р-н
# 692  ул.Садовая, 2 (метро - "Гостиный двор","Невски...
# 693                   Санкт-Петербург, 197046 o.Заячий
#
#                            Телефоны  \
# 0    +7(812)5704108; +7(812)7105061
# 1                    +7(812)3505301
# 2                    +7(981)7559605
# 3                +7 (812) 233-00-05
# 4                    +7(812)4984075
# ..                              ...
# 689              +7 (812) 233-00-05
# 690              +7 (812) 233-00-05
# 691               +7 812) 242-33-77
# 692              +7 (812) 595-42-48
# 693              +7 (812) 230-64-31
#
#                                                  Сайт  \
# 0                                 armenian-church.org
# 1                                 armenian-church.org
# 2                                        dazan.spb.ru
# 3                                                 нет
# 4                                          dum-spb.ru
# ..                                                ...
# 689                                               нет
# 690                                               нет
# 691  http://oopt.spb.ru/protected_area/novoorlovskiy/
# 692                                  www.rusmuseum.ru
# 693                                  www.spbmuseum.ru
#
#              Электронная почта  \
# 0       arm_church_spb@mail.ru
# 1       arm_church_spb@mail.ru
# 2                          нет
# 3                          нет
# 4              dum-spb@mail.ru
# ..                         ...
# 689                        нет
# 690                        нет
# 691  dep@oopt.kpoos.gov.spb.ru
# 692          info@rusmuseum.ru
# 693           gmi@spbmuseum.ru
#
#                                               Описание  \
# 0    Здание было построено архитектором Ю. М. Фельт...
# 1    Возведенная в традициях русского классицизма, ...
# 2    "Оригинальный храм из красно-фиолетового грани...
# 3    Коломяжскую мечеть, расположившуюся в Приморск...
# 4    "Здание Соборной мечети – яркий образец архите...
# ..                                                 ...
# 689  В Ленинградской области в деревне Лопухинка ес...
# 690  Три Суздальских озера расположены недалеко дру...
# 691  Растительный покров Новоорловского заказника н...
# 692  Михайловский или Инженерный замок - бывший имп...
# 693  В 1908 году по инициативе известных исследоват...
#
#                                       Описание (англ.)  \
# 0                                        круглосуточно
# 1                                        круглосуточно
# 2                                        круглосуточно
# 3                                        круглосуточно
# 4                                        круглосуточно
# ..                                                 ...
# 689  In the Leningrad region, in the village of Lop...
# 690  Three Suzdal lakes are located not far from ea...
# 691  Растительный покров Новоорловского заказника н...
# 692  St. Michael's Castle (also called the Mikhailo...
# 693  The Museum of Old Petersburg was initiated in ...
#
#                                   Историческая справка  \
# 0    22 мая (2 июня) 1770 года по челобитной главы ...
# 1    "Храм строился по инициативе и на средства гла...
# 2    Санкт-Петербургский буддийский храм был постро...
# 3    Квартальная джума-мечеть построена по заказу Д...
# 4    "Еще в конце XVIII века около 500 нижних чинов...
# ..                                                 ...
# 689                                         не указано
# 690                                         не указано
# 691  Первое письменное упоминание населенных пункто...
# 692                                         не указано
# 693                                         не указано
#
#                           Историческая справка (англ.)  \
# 0    1st  Engineer Bridge is one of several bridges...
# 1    1st  Engineer Bridge is one of several bridges...
# 2    1st  Engineer Bridge is one of several bridges...
# 3    1st  Engineer Bridge is one of several bridges...
# 4    1st  Engineer Bridge is one of several bridges...
# ..                                                 ...
# 689  1st  Engineer Bridge is one of several bridges...
# 690  1st  Engineer Bridge is one of several bridges...
# 691  The first written mention of settlements locat...
# 692  1st  Engineer Bridge is one of several bridges...
# 693  1st  Engineer Bridge is one of several bridges...
#
#                                                Заметки  \
# 0    "Крестовский остров": идти от метро по Рюхиной...
# 1    "Крестовский остров": идти от метро по Рюхиной...
# 2    "Крестовский остров": идти от метро по Рюхиной...
# 3    "Крестовский остров": идти от метро по Рюхиной...
# 4    Часы работы не указаны. Можно записаться на эк...
# ..                                                 ...
# 689  Как добраться: электричкой от Балтийского вокз...
# 690        Как добраться: пешком от ст. метро "Озерки"
# 691  Добраться до заказника можно: от станции метро...
# 692  "Крестовский остров": идти от метро по Рюхиной...
# 693  "Крестовский остров": идти от метро по Рюхиной...
#
#                                           Режим работы Режим работы (англ.)  \
# 0                                09:00–19:00, ежеднвно             24 hours
# 1                               09:00–18:00, ежедневно             24 hours
# 2    Ежедневно с 10:00 до 19:00. Выходной день - ср...             24 hours
# 3                              Понедельник 12:00-20:00             24 hours
# 4                                        Круглосуточно             24 hours
# ..                                                 ...                  ...
# 689                                      Круглосуточно             24 hours
# 690                                      Круглосуточно             24 hours
# 691  Работает ежедневно, круглосуточно выходные бес...             24 hours
# 692                                      Круглосуточно             24 hours
# 693                                      Круглосуточно             24 hours
#
#                     Координаты  Координата_X  Координата_Y
# 0    59.957114107,30.303121017     59.957114     30.303121
# 1    59.947875533,30.253260955     59.947876     30.253261
# 2    59.983492135,30.255973046     59.983492     30.255973
# 3    60.017749506,30.281070461     60.017750     30.281070
# 4     59.955200609,30.32390419     59.955201     30.323904
# ..                         ...           ...           ...
# 689        59.734545,29.401247     59.734545     29.401247
# 690         60.057625,30.30438     60.057625     30.304380
# 691          60.049967,30.2892     60.049967     30.289200
# 692  59.940205114,30.337045054     59.940205     30.337045
# 693        59.950154,30.315877     59.950154     30.315877
#
# [693 rows x 20 columns]

# %% [markdown]
# #### 14. Фильтрация. Выберите все строки таблицы, для которых значение поля Название равно Николаю II

# %%
# Ваш код здесь

data[data['Название'] == 'Николаю II']
# Out:
#      ID в ИС ГТИБД Вид объекта    Название       Краткое название  \
# 406           9037   Памятники  Николаю II  Церковь Петра и Павла
# 461          10341   Памятники  Николаю II  Церковь Петра и Павла
#
#                 Название (англ.)              Тип учреждения  \
# 406  The monument to Nickolay II  некоммерческая организация
# 461  The monument to Nickolay II  некоммерческая организация
#
#                                         Адрес (ручной)            Телефоны  \
# 406  г. Пушкин, Академический пр., 34, в ограде Фед...  +7 (812) 233-00-05
# 461  г. Санкт-Петербург, Лиговский пр., 128, в огра...  +7 (812) 233-00-05
#
#     Сайт Электронная почта                                           Описание  \
# 406  нет               нет  В нескольких десятках метров к юго-западу от х...
# 461  нет               нет  Открыт 19 мая 2002 г. Скульптор: Алипов С. Ю. ...
#
#                                       Описание (англ.) Историческая справка  \
# 406  Sculptor: Zayko V. It was erected on the 17th ...           не указано
# 461  It was erected on 19th May, 2002. Sculptor: Al...           не указано
#
#                           Историческая справка (англ.)  \
# 406  1st  Engineer Bridge is one of several bridges...
# 461  1st  Engineer Bridge is one of several bridges...
#
#                                                Заметки     Режим работы  \
# 406  "Крестовский остров": идти от метро по Рюхиной...  c 9.00 до 19.00
# 461  "Крестовский остров": идти от метро по Рюхиной...  c 9.00 до 19.00
#
#         Режим работы (англ.)                 Координаты  Координата_X  \
# 406  from 9 a.m. till 7 p.m.  59.725809489,30.390682904     59.725809
# 461   from 9 a.m till 7 p.m.        59.916167,30.354072     59.916167
#
#      Координата_Y
# 406     30.390683
# 461     30.354072

# %% [markdown]
# #### 15. Фильтрация. Выберите все строки таблицы, для которых значение поля Заметки равно "Крестовский остров": идти от метро по Рюхиной улице до пересечения с набережной Мартынова, перед вами вход в парк на 2-й Елагин мост. "Старая деревня": идти по Липовой аллее до пересечения с Приморским проспектом, перед вами вход в парк и 3-й Елагин мост. Станции метро: «Крестовский остров», «Старая деревня»; Трамваи: 2, 21, 48; Автобусы: 32, 93; Маршрутные такси: 93, 206, 210, 132, 133, 179А, 222, 308, 690. и значение поля Электронная почта равно нет

# %%
# Ваш код здесь
data[
    (data['Заметки'] == '"Крестовский остров": идти от метро по Рюхиной улице до пересечения с набережной Мартынова, перед вами вход в парк на 2-й Елагин мост. "Старая деревня": идти по Липовой аллее до пересечения с Приморским проспектом, перед вами вход в парк и 3-й Елагин мост. Станции метро: «Крестовский остров», «Старая деревня»; Трамваи: 2, 21, 48; Автобусы: 32, 93; Маршрутные такси: 93, 206, 210, 132, 133, 179А, 222, 308, 690.')
    &
    (data['Электронная почта'] == 'нет')
]
# Out:
#      ID в ИС ГТИБД          Вид объекта  \
# 2             5829  Религиозные объекты
# 3             5830  Религиозные объекты
# 9             5836  Религиозные объекты
# 11            5838  Религиозные объекты
# 12            5839  Религиозные объекты
# ..             ...                  ...
# 661           6928                Мосты
# 662           6929                Мосты
# 663           6930                Мосты
# 664           6931                Мосты
# 680          13793    Природные объекты
#
#                                               Название  \
# 2    Санкт-Петербургский буддийский храм Дацан Гунз...
# 3                                   Коломяжская мечеть
# 9    Приход Матери Божией Лурдской Римско-католичес...
# 11   Приход Святейшего Сердца Иисуса в Санкт-Петерб...
# 12     Храм Посещения Пресвятой Девой Марией Елизаветы
# ..                                                 ...
# 661                                Чернореченский мост
# 662                                 Строгановский мост
# 663                                   Головинский мост
# 664                              Большой Ижорский мост
# 680                                    Левашовский лес
#
#                                     Краткое название  \
# 2                                  Дацан Гунзэчойнэй
# 3                                 Коломяжская мечеть
# 9                     Церковь Лурдской Божией Матери
# 11                     Храм Святейшего Сердца Иисуса
# 12   Храм Посещения Пресвятой Девой Марией Елизаветы
# ..                                               ...
# 661                            Церковь Петра и Павла
# 662                            Церковь Петра и Павла
# 663                            Церковь Петра и Павла
# 664                            Церковь Петра и Павла
# 680                                  Левашовский лес
#
#                   Название (англ.)              Тип учреждения  \
# 2              Datsan Gunzechoinei  некоммерческая организация
# 3            Kolomyazhskaya Mosque  некоммерческая организация
# 9       Lourdskaya St. Mary Church  некоммерческая организация
# 11   Jesus Holiest Heart Cathedral  некоммерческая организация
# 12            Visitation Cathedral  некоммерческая организация
# ..                             ...                         ...
# 661         Chernorechensky Bridge  некоммерческая организация
# 662            Stroganovsky Bridge  некоммерческая организация
# 663              Golovinsky Bridge  некоммерческая организация
# 664        Bolshoy Izhorsky Bridge  некоммерческая организация
# 680             Levashovsky forest  некоммерческая организация
#
#                                         Адрес (ручной)  \
# 2                Санкт-Петербург, Приморский пр., д.91
# 3                   Санкт-Петербург, Репищева ул., д.1
# 9                 Санкт-Петербург, Ковенский пер., д.7
# 11                Санкт-Петербург, ул. Бабушкина, д.57
# 12        Санкт-Петербург, Минеральная ул., 21 литер Д
# ..                                                 ...
# 661               Санкт-Петербург, Чернореченский мост
# 662                Санкт-Петербург, Строгановский мост
# 663                  Санкт-Петербург, Головинский мост
# 664             Санкт-Петербург, Большой Ижорский мост
# 680  Находится в пределах города Сестрорецк Курортн...
#
#                                            Телефоны  \
# 2                                    +7(981)7559605
# 3                                +7 (812) 233-00-05
# 9    +7(911)2095953; +7(812)2725002; +7(812)2720442
# 11                                   +7(921)3750125
# 12        7 (812) 310 04 66       7 (911) 194 62 76
# ..                                              ...
# 661                              +7 (812) 233-00-05
# 662                              +7 (812) 233-00-05
# 663                              +7 (812) 233-00-05
# 664                              +7 (812) 233-00-05
# 680                              +7 (812) 233-00-05
#
#                                                   Сайт Электронная почта  \
# 2                                         dazan.spb.ru               нет
# 3                                                  нет               нет
# 9                                      www.kovensky.ru               нет
# 11                              www.sacredheart.spb.ru               нет
# 12                                   www.visitmaria.ru               нет
# ..                                                 ...               ...
# 661                                                нет               нет
# 662                                                нет               нет
# 663                                                нет               нет
# 664                                                нет               нет
# 680  http://oopt.aari.ru/oopt/%D0%9B%D0%B5%D0%B2%D0...               нет
#
#                                               Описание  \
# 2    "Оригинальный храм из красно-фиолетового грани...
# 3    Коломяжскую мечеть, расположившуюся в Приморск...
# 9    "Облик католического храма вышел на редкость а...
# 11   Пожалуй, самая каноничная готическая церковь в...
# 12   Костел выполнен в формах раннеготической архит...
# ..                                                 ...
# 661                                            Церковь
# 662                                            Церковь
# 663                                            Церковь
# 664                                            Церковь
# 680  Леса представлены всеми основными древесными п...
#
#                                       Описание (англ.)  \
# 2                                        круглосуточно
# 3                                        круглосуточно
# 9                                        круглосуточно
# 11                                       круглосуточно
# 12                                       круглосуточно
# ..                                                 ...
# 661                                      круглосуточно
# 662                                      круглосуточно
# 663                                      круглосуточно
# 664                                      круглосуточно
# 680  Levashovsky forests are represented by all the...
#
#                                   Историческая справка  \
# 2    Санкт-Петербургский буддийский храм был постро...
# 3    Квартальная джума-мечеть построена по заказу Д...
# 9    Построен в 1903-1909 годах для нужд французско...
# 11   "В 1892 году несколько тысяч католиков, прожив...
# 12   "В 1852 году католическое духовенство Санкт-Пе...
# ..                                                 ...
# 661  Чернореченский мост - мост через Чёрную речку ...
# 662  Строгановский мост - пешеходный мост в Приморс...
# 663  Головинский мост - соединяет берега Чёрной реч...
# 664  Большой Ижорский мост - мост через разлив реки...
# 680  Сделать Левашовский лес охраняемой территорий ...
#
#                           Историческая справка (англ.)  \
# 2    1st  Engineer Bridge is one of several bridges...
# 3    1st  Engineer Bridge is one of several bridges...
# 9    1st  Engineer Bridge is one of several bridges...
# 11   1st  Engineer Bridge is one of several bridges...
# 12   1st  Engineer Bridge is one of several bridges...
# ..                                                 ...
# 661  Chernorechensky Bridge is a bridge across Chyo...
# 662  Stroganovsky Bridge is a pedestrian bridge in ...
# 663  Golovinsky Bridge connects the banks of Chyorn...
# 664  Bolshoy Izhorsky Bridge is a bridge across the...
# 680  Levashovsky forest was already supposed to bec...
#
#                                                Заметки  \
# 2    "Крестовский остров": идти от метро по Рюхиной...
# 3    "Крестовский остров": идти от метро по Рюхиной...
# 9    "Крестовский остров": идти от метро по Рюхиной...
# 11   "Крестовский остров": идти от метро по Рюхиной...
# 12   "Крестовский остров": идти от метро по Рюхиной...
# ..                                                 ...
# 661  "Крестовский остров": идти от метро по Рюхиной...
# 662  "Крестовский остров": идти от метро по Рюхиной...
# 663  "Крестовский остров": идти от метро по Рюхиной...
# 664  "Крестовский остров": идти от метро по Рюхиной...
# 680  "Крестовский остров": идти от метро по Рюхиной...
#
#                                           Режим работы Режим работы (англ.)  \
# 2    Ежедневно с 10:00 до 19:00. Выходной день - ср...             24 hours
# 3                              Понедельник 12:00-20:00             24 hours
# 9    пн-пт 08:30-19:30, перерыв 10:00-16:00; вс 08:...             24 hours
# 11                          Храм закрыт на реставрацию             24 hours
# 12                              ежедневно, 10:00–20:00             24 hours
# ..                                                 ...                  ...
# 661                                      Круглосуточно             24 hours
# 662                                      Круглосуточно             24 hours
# 663                                      Круглосуточно             24 hours
# 664                                      Круглосуточно             24 hours
# 680  Посещение заказника без механических транспорт...             24 hours
#
#                     Координаты  Координата_X  Координата_Y
# 2    59.983492135,30.255973046     59.983492     30.255973
# 3    60.017749506,30.281070461     60.017750     30.281070
# 9    59.937107794,30.356808256     59.937108     30.356808
# 11   59.880613765,30.436622564     59.880614     30.436623
# 12    59.96626157,30.369133454     59.966262     30.369133
# ..                         ...           ...           ...
# 661        59.986421,30.302609     59.986421     30.302609
# 662        59.984175,30.310236     59.984175     30.310236
# 663        59.981096,30.317153     59.981096     30.317153
# 664        59.740611,30.597373     59.740611     30.597373
# 680         60.11185,30.025503     60.111850     30.025503
#
# [533 rows x 20 columns]

# %% [markdown]
# #### 16. Получите все уникальные значения поля  Электронная почта и подсчитайте частоту появления каждого их них

# %%
# Ваш код здесь

data['Электронная почта'].unique()
data['Электронная почта'].value_counts()
# Out:
# Электронная почта
# нет                            541
# oopt.spb@gmail.com              14
# н/д                              7
# не указано                       3
# office@cathedral.ru              2
#                               ...
# park_monrepo@mail.ru             1
# a.smirnov.vepsles@yandex.ru      1
# dep@oopt.kpoos.gov.spb.ru        1
# info@rusmuseum.ru                1
# gmi@spbmuseum.ru                 1
# Name: count, Length: 127, dtype: int64

# %% [markdown]
# #### 17. Выполните группировку набора данных одновременно по полям Название и Телефоны. Добавьте подсчет минимума, максимума и медианы по каждой группе.

# %%
# Ваш код здесь
grouped = data.groupby(['Название', 'Телефоны']).agg({
    'Координата_X': ['min', 'max', 'median'],
    'Координата_Y': ['min', 'max', 'median']
})

grouped
# Out:
#                                                                                 Координата_X  \
#                                                                                          min
# Название                                           Телефоны
# " Мемориальный комплекс памяти пожарных, погибш... +7(812)5424652; +79110035260    59.965645
# 1-й Волковский мост                                +7 (812) 233-00-05              59.899523
# 1-й Елагин мост                                    +7 (812) 233-00-05              59.977481
# 1-й Зимний мост                                    +7 (812) 233-00-05              59.941457
# 1-й Инженерный мост                                +7 (812) 233-00-05              59.941768
# ...                                                                                      ...
# Юнкерам Николаевского кавалерийского училища       +7 (812) 233-00-05              59.910582
# Юсуповский сад                                     +7 (812) 233-00-05              59.922779
# Яблоневый сад                                      +7 (812) 233-00-05              59.863574
# Яблоновский мост                                   +7 (812) 233-00-05              59.927252
# Яковлевой М. Я.                                    +7 (812) 233-00-05              59.866961
#
#                                                                                             \
#                                                                                        max
# Название                                           Телефоны
# " Мемориальный комплекс памяти пожарных, погибш... +7(812)5424652; +79110035260  59.965645
# 1-й Волковский мост                                +7 (812) 233-00-05            59.899523
# 1-й Елагин мост                                    +7 (812) 233-00-05            59.977481
# 1-й Зимний мост                                    +7 (812) 233-00-05            59.941457
# 1-й Инженерный мост                                +7 (812) 233-00-05            59.941768
# ...                                                                                    ...
# Юнкерам Николаевского кавалерийского училища       +7 (812) 233-00-05            59.910582
# Юсуповский сад                                     +7 (812) 233-00-05            59.922779
# Яблоневый сад                                      +7 (812) 233-00-05            59.863574
# Яблоновский мост                                   +7 (812) 233-00-05            59.927252
# Яковлевой М. Я.                                    +7 (812) 233-00-05            59.866961
#
#                                                                                             \
#                                                                                     median
# Название                                           Телефоны
# " Мемориальный комплекс памяти пожарных, погибш... +7(812)5424652; +79110035260  59.965645
# 1-й Волковский мост                                +7 (812) 233-00-05            59.899523
# 1-й Елагин мост                                    +7 (812) 233-00-05            59.977481
# 1-й Зимний мост                                    +7 (812) 233-00-05            59.941457
# 1-й Инженерный мост                                +7 (812) 233-00-05            59.941768
# ...                                                                                    ...
# Юнкерам Николаевского кавалерийского училища       +7 (812) 233-00-05            59.910582
# Юсуповский сад                                     +7 (812) 233-00-05            59.922779
# Яблоневый сад                                      +7 (812) 233-00-05            59.863574
# Яблоновский мост                                   +7 (812) 233-00-05            59.927252
# Яковлевой М. Я.                                    +7 (812) 233-00-05            59.866961
#
#                                                                                 Координата_Y  \
#                                                                                          min
# Название                                           Телефоны
# " Мемориальный комплекс памяти пожарных, погибш... +7(812)5424652; +79110035260    30.351368
# 1-й Волковский мост                                +7 (812) 233-00-05              30.359679
# 1-й Елагин мост                                    +7 (812) 233-00-05              30.271581
# 1-й Зимний мост                                    +7 (812) 233-00-05              30.318716
# 1-й Инженерный мост                                +7 (812) 233-00-05              30.337796
# ...                                                                                      ...
# Юнкерам Николаевского кавалерийского училища       +7 (812) 233-00-05              30.298772
# Юсуповский сад                                     +7 (812) 233-00-05              30.309152
# Яблоневый сад                                      +7 (812) 233-00-05              30.363651
# Яблоновский мост                                   +7 (812) 233-00-05              30.436683
# Яковлевой М. Я.                                    +7 (812) 233-00-05              30.469204
#
#                                                                                             \
#                                                                                        max
# Название                                           Телефоны
# " Мемориальный комплекс памяти пожарных, погибш... +7(812)5424652; +79110035260  30.351368
# 1-й Волковский мост                                +7 (812) 233-00-05            30.359679
# 1-й Елагин мост                                    +7 (812) 233-00-05            30.271581
# 1-й Зимний мост                                    +7 (812) 233-00-05            30.318716
# 1-й Инженерный мост                                +7 (812) 233-00-05            30.337796
# ...                                                                                    ...
# Юнкерам Николаевского кавалерийского училища       +7 (812) 233-00-05            30.298772
# Юсуповский сад                                     +7 (812) 233-00-05            30.309152
# Яблоневый сад                                      +7 (812) 233-00-05            30.363651
# Яблоновский мост                                   +7 (812) 233-00-05            30.436683
# Яковлевой М. Я.                                    +7 (812) 233-00-05            30.469204
#
#
#                                                                                     median
# Название                                           Телефоны
# " Мемориальный комплекс памяти пожарных, погибш... +7(812)5424652; +79110035260  30.351368
# 1-й Волковский мост                                +7 (812) 233-00-05            30.359679
# 1-й Елагин мост                                    +7 (812) 233-00-05            30.271581
# 1-й Зимний мост                                    +7 (812) 233-00-05            30.318716
# 1-й Инженерный мост                                +7 (812) 233-00-05            30.337796
# ...                                                                                    ...
# Юнкерам Николаевского кавалерийского училища       +7 (812) 233-00-05            30.298772
# Юсуповский сад                                     +7 (812) 233-00-05            30.309152
# Яблоневый сад                                      +7 (812) 233-00-05            30.363651
# Яблоновский мост                                   +7 (812) 233-00-05            30.436683
# Яковлевой М. Я.                                    +7 (812) 233-00-05            30.469204
#
# [693 rows x 6 columns]

# %% [markdown]
# #### 18. Постройте поле корреляции (тепловая карта) для числовых полей

# %%
# Ваш код здесь

numeric_data = data.select_dtypes(include=np.number)

corrmat = numeric_data.corr()

plt.figure(figsize=(10,8))
sns.heatmap(corrmat, annot=True, square=True)

plt.title('Корреляционная матрица')
plt.show()

# %% [markdown]
# #### 19. Постройте гистограмму по полю ID в ИС ГТИБД

# %%
# Ваш код здесь
plt.figure(figsize=(8,5))

plt.hist(data['ID в ИС ГТИБД'], bins=20)

plt.title('Гистограмма ID в ИС ГТИБД')
plt.xlabel('ID')
plt.ylabel('Количество')

plt.show()

# %% [markdown]
# #### 20. Постройте точечную диаграмму для полей Координата_Y и ID в ИС ГТИБД

# %%
# Ваш код здесь
plt.figure(figsize=(8,5))

plt.scatter(data['Координата_Y'], data['ID в ИС ГТИБД'])

plt.xlabel('Координата_Y')
plt.ylabel('ID в ИС ГТИБД')

plt.title('Точечная диаграмма')

plt.show()

# %% [markdown]
# #### 21. Постройте диаграмму ящик с усами поля Координата_Y

# %%
# Ваш код здесь. Также напишите о наличии выбросов в этом поле
plt.figure(figsize=(8,5))

sns.boxplot(data['Координата_Y'])

plt.title('Boxplot Координата_Y')

plt.show()

# %% [markdown]
# #### 22. Постройте матрицу диаграммы рассеяния

# %%
# Ваш код здесь
num_data = data.select_dtypes(include=['float64', 'int64'])


sns.pairplot(num_data)

plt.show()

# %% [markdown]
# #### 23. Преобразуйте все категориальные поля в числовые с помощью LabelEncoder

# %%
# Ваш код здесь
from sklearn.preprocessing import LabelEncoder

data_encoded = data.copy()

le = LabelEncoder()

for col in data_encoded.columns:

    if data_encoded[col].dtype == 'object':
        data_encoded[col] = le.fit_transform(data_encoded[col].astype(str))


data_encoded.head()
# Out:
#    ID в ИС ГТИБД  Вид объекта  Название  Краткое название  Название (англ.)  \
# 0           5827            4        42                 4               414
# 1           5828            4        41               137               445
# 2           5829            4       477                12                94
# 3           5830            4       214                33               174
# 4           5831            4       507                69               367
#
#    Тип учреждения  Адрес (ручной)  Телефоны  Сайт  Электронная почта  \
# 0              31             293       110     5                  9
# 1              31             412        72     5                  9
# 2              31             328       158    12                126
# 3              31             331         3   172                126
# 4              31             247        97    14                 17
#
#    Описание  Описание (англ.)  Историческая справка  \
# 0       148               272                    80
# 1       100               272                    56
# 2        20               272                   295
# 3       170               272                   180
# 4        13               272                    30
#
#    Историческая справка (англ.)  Заметки  Режим работы  Режим работы (англ.)  \
# 0                             0        0            36                    20
# 1                             0        0            34                    20
# 2                             0        0           102                    20
# 3                             0        0           121                    20
# 4                             0       24           111                    20
#
#    Координаты  Координата_X  Координата_Y
# 0         490     59.957114     30.303121
# 1         451     59.947876     30.253261
# 2         557     59.983492     30.255973
# 3         608     60.017750     30.281070
# 4         480     59.955201     30.323904

# %% [markdown]
# #### 24. Сделайте вывод о проделанной работе и особенностях набора данных

# %% [markdown]
# В ходе выполнения задания был проведен разведочный анализ данных для набора данных «Достопримечательности Санкт-Петербурга». Были использованы библиотеки pandas, numpy, matplotlib, seaborn. Особенности набора данных заключаются в том, что набор данных включает как текстовые (название, заметки, телефоны), так и числовые данные (координаты); возможны пропуски в отдельных полях; данные подходят для анализа географического распределения объектов; после преобразования категориальных признаков может использоваться для задач машинного обучения. Проведенный анализ показал, что набор данных является структурированным и пригодным для дальнейшего анализа и построения моделей. Основные этапы анализа позволили изучить распределение данных, выявить их особенности и подготовить датасет к дальнейшей обработке.
